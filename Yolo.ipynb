# %%
#importação da biblioteca e carregamento do modelo
from ultralytics import YOLO

model = YOLO("yolov8n-cls.pt")

# %%
#caminho do dataset
caminho = "/home/lucas/Documentos/Lamia/ProjetoFinal/data/dataset_final/"

results = model.train(
    data=caminho,
    epochs=100, #qnt de epocas
    imgsz=224, #tamanho da imagem
    augment=True,  #augment 

    #transformações leves do augmente
    degrees=20.0,         
    translate=0.2,        
    scale=0.6,            
    shear=5.0,            
    hsv_s=0.8,            
    hsv_v=0.5,            
    flipud=0.1,           
    mixup=0.15,          
    erasing=0.5           
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.228 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.204 🚀 Python-3.10.18 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 5814MiB)
# ...

# %%
#Carregamento melhor modelo e teste no dataset de teste
from ultralytics import YOLO

model = YOLO('runs/classify/train8/weights/best.pt')

metrics = model.val(data='data/dataset.yaml',split='test', verbose=True)

print(metrics.top1)
# Out:
# Ultralytics 8.3.204 🚀 Python-3.10.18 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 5814MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,440,004 parameters, 0 gradients, 3.3 GFLOPs
# test: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2470.4±732.5 MB/s, size: 50.0 KB)
# test: Scanning /home/lucas/Documentos/Lamia/ProjetoFinal/data/dataset_final/test... 637 images, 0 corrupt: 100% ━━━━━━━━━━━━ 637/637 2.1Kit/s 0.3s<0.3s
# test: New cache created: /home/lucas/Documentos/Lamia/ProjetoFinal/data/dataset_final/test.cache
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 40/40 27.3it/s 1.5s0.1s
#                    all      0.929          1
# Speed: 0.2ms preprocess, 0.9ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /home/lucas/Documentos/Lamia/ProjetoFinal/runs/classify/val21
# 0.9293563365936279
