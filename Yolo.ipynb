# %%
#importação da biblioteca e carregamento do modelo
from ultralytics import YOLO

model = YOLO("yolov8n-cls.pt")

# %%
#caminho do dataset
caminho = "/home/lucas/Documentos/Lamia/ProjetoFinal/data/dataset_eye_disease"

results = model.train(
    data=caminho,
    epochs=100, #qnt de epocas
    imgsz=224, #tamanho da imagem
    augment=True,  #augment 

    #transformações leves do augmente
    degrees=20.0,         
    translate=0.2,        
    scale=0.6,            
    shear=5.0,            
    hsv_s=0.8,            
    hsv_v=0.5,            
    flipud=0.1,           
    mixup=0.15,          
    erasing=0.5           
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.213 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.204 🚀 Python-3.10.18 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 5815MiB)
# ...

# %%
from ultralytics import YOLO

# Carregue o seu NOVO e MELHOR modelo
model = YOLO('runs/classify/train5/weights/best.pt') # Use o caminho do último treino!

# Valide no seu dataset externo
metrics = model.val(data='data/data_validation/')

print(f"Acurácia final no dataset externo: {metrics.top1:.2%}")
# Out:
# Ultralytics 8.3.204 🚀 Python-3.10.18 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 5815MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,440,004 parameters, 0 gradients, 3.3 GFLOPs
# WARNING ⚠️ Dataset 'split=train' not found at /home/lucas/Documentos/Lamia/ProjetoFinal/data/data_validation/train
# Found 30 images in subdirectories. Attempting to split...
# Splitting /home/lucas/Documentos/Lamia/ProjetoFinal/data/data_validation (4 classes, 40 images) into 80% train, 20% val...
# Split complete in /home/lucas/Documentos/Lamia/ProjetoFinal/data/data_validation_split ✅
# train: /home/lucas/Documentos/Lamia/ProjetoFinal/data/data_validation_split/train... found 37 images in 4 classes ✅
# val: /home/lucas/Documentos/Lamia/ProjetoFinal/data/data_validation_split/val... found 13 images in 4 classes ✅
# test: None...
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3787.6±1669.0 MB/s, size: 1817.5 KB)
# ...
